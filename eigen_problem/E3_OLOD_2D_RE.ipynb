# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(),"..")))
from setup_path import add_repo_paths
add_repo_paths()

# %%
import numpy as np
import scipy.io as sio
import time
from offline_online_alg import *
from convergence import *
from MLOD_alg import *
from plots import *
from Experimental_Order_Cvg import *

# %%
#NFine = np.array([256,256])
#Nepsilon = np.array([64,64])
#NCoarse = np.array([4,4])
#k=3
#NSamples = 200
#dim = np.size(NFine)
#Neigen = 3
#alpha = 0.1
#beta = 1
#left = np.array([0.25, 0.25])
#right = np.array([0.75, 0.75])
#pList =  [0.02, 0.04, 0.06, 0.08, 0.1]
#def_value = [alpha] #, 0.5, 5.]
#value = alpha
#modelincl = {'name': 'inclvalue', 'bgval': alpha, 'inclval': beta, 'left': left, 'right': right, 'defval': value} #modelincl = {'name': 'incl', 'bgval': alpha, 'inclval': beta, 'left': left, 'right': right}
#np.random.seed(1)

# %%
root = 'All_Data/OO_2D_randerasure/folder_1/'

# %%
plots_cvg(root, p_Convergence=True, dim=2)
# Out:
# hplot [ 8 16 32 64]

# %% [markdown]
# Random erasure

# %%
NFine = np.array([256,256])
Nepsilon = np.array([32,32])
NCoarse = np.array([8,8])
k=3
NSamples = 200
dim = np.size(NFine)
Neigen = 3
alpha = 0.1
beta = 1
left = np.array([0.25, 0.25])
right = np.array([0.75, 0.75])
pList = [0.2]
def_values = [alpha, 0.5, 5.]
modelincl = {'name': 'incl', 'bgval': alpha, 'inclval': beta, 'left': left, 'right': right}
np.random.seed(1)

# %%
plots_coeffs(Nepsilon, NFine, alpha, beta, pList, "random_erasure")
