# %%
from plots import *
import numpy as np

# %% [markdown]
# Comparison between sum constraint one and $s \in \mathbb{R}^+$ models

# %%
# NFine = np.array([256, 256])
# Nepsilon = np.array([128, 128])
# NCoarse = np.array([4, 4])  
# k=3
# NSamples = 200
# dim = np.size(NFine)
# Neigen = 3
# alpha = 0.1
# beta = 1.
# pList = [0.01,0.05,0.1,0.15, 0.2]
# np.random.seed(1)
# model ={'name': 'check', 'alpha': alpha, 'beta': beta}

# %%
root1 = 'All_Data/OO_2D_randcheck/folder_sp/'
root2 ='All_Data/OO_2D_Rand_sval/folder_sp/'

# %%
plot_s_vs_unity_errors(root1, root2)

# %% [markdown]
# Alternate model

# %%
# NFine = np.array([256, 256])
# Nepsilon = np.array([128, 128])
# NCoarse = np.array([4, 4])
# k=3
# NSamples = 200
# dim = np.size(NFine)
# Neigen = 3
# boundaryConditions = None
# alpha = 0.1
# beta = 1.
# pList = [0.002,0.004,0.006,0.008, 0.01]
# np.random.seed(1)
# model ={'name': 'check', 'alpha': alpha, 'beta': beta}
# root = 'All_Data/OO_2D_Rand_sval/folder_1/'
