# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(),"..")))
from setup_path import add_repo_paths
add_repo_paths()

# %%
from plots import *
import numpy as np

# %%
# NFine = np.array([256])
# Nepsilon = np.array([128])
# NCoarse = np.array([4])
# k=3
# NSamples = 200
# dim = np.size(NFine)
# Neigen = 3
# alpha = 0.1
# beta = 1.
# pList = [0.02,0.1,0.15, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]
# np.random.seed(1)
# model ={'name': 'check', 'alpha': alpha, 'beta': beta}

# %%
root2 ='All_Data/OO_1D_Rand_sval/folder_4n/'
root1='All_Data/OO_1D_randcheck/folder_4n/'

# %%
plot_s_vs_unity_errors(root1, root2)

# %% [markdown]
# Alternate algorithm errors in comparison to FEM

# %%
# NFine = np.array([256])
# Nepsilon = np.array([128])
# NCoarse = np.array([4])
# k=3
# NSamples = 200
# dim = np.size(NFine)
# Neigen = 3
# alpha = 0.1
# beta = 1.
# pList = [0.02,0.04,0.06,0.08,0.1]
# np.random.seed(1)
# model ={'name': 'check', 'alpha': alpha, 'beta': beta}

# %%
root3 ='All_Data/OO_1D_Rand_sval/folder_1/'

# %%
plots_cvg(root3, H_Convergence=True, p_Convergence=True, dim=1)
# Out:
# hplot [ 8 16 32 64]
